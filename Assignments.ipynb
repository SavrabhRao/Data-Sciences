# %% [markdown]
# # ASSIGNMENT 1

# %%
# create bmi calculator
age = int(input("Enter your age between (2 - 120): "))
if age >=2 and age < 20 :
    gender = input("For your BMI Report Enter your Gender (Male/Female): ")
    if gender == "Male" or gender == "male"  :
        a = eval(input("Enter your weight in kg: "))
        b = eval(input("Enter your height in Meter: "))
        height_square = b*b
        BMI = a/height_square
        print("Your BMI is : " ,BMI)
        if BMI<16 :
            print("Severe Thinness")
        elif BMI >=16 and BMI <17 :
            print("Moderate Thinness")
        elif BMI >=17 and BMI < 18.5 :
            print("Mild Thinness")
        elif BMI >=18.5 and BMI <25 :
            print("normal")
        elif BMI >=25 and BMI <30 : 
            print("Overweight")
        elif BMI >=30 and BMI <35 :
            print("Obese Class I")
        elif BMI >=35 and BMI <40 :
            print("Obese Class II")
        elif BMI >=40 :
            print("Obese Class III") 
    
    elif gender == "Female" or gender == "female":
        a = eval(input("Enter your weight in kg: "))
        b = eval(input("Enter your height in Meter: "))
        height_square = b*b
        BMI = a/height_square
        print("Your BMI is : " , BMI)
        if BMI<16 :
            print("Severe Thinness")
        elif BMI >=16 and BMI <17 :
            print("Moderate Thinness")
        elif BMI >=17 and BMI < 18.5 :
            print("Mild Thinness")
        elif BMI >=18.5 and BMI <25 :
            print("normal")
        elif BMI >=25 and BMI <30 : 
            print("Overweight")
        elif BMI >=30 and BMI <35 :
            print("Obese Class I")
        elif BMI >=35 and BMI <40 :
            print("Obese Class II")
        elif BMI >=40 :
            print("Obese Class III") 
    else:
        print("Invalid Gender")
    
    
elif age >=20 and age<=120 :
    gender = input("For your BMI Report Enter your Gender (Male/Female): ")
    if gender == "Male" or gender == "male" :
        a = eval(input("Enter your weight in kg: "))
        b = eval(input("Enter your height in Meter: "))
        height_square = b*b
        BMI = a/height_square
        print("Your BMI is : " , BMI)
        if BMI<16 :
            print("Severe Thinness")
        elif BMI >=16 and BMI <17 :
            print("Moderate Thinness")
        elif BMI >=17 and BMI < 18.5 :
            print("Mild Thinness")
        elif BMI >=18.5 and BMI <25 :
            print("normal")
        elif BMI >=25 and BMI <30 : 
            print("Overweight")
        elif BMI >=30 and BMI <35 :
            print("Obese Class I yes this one")
        elif BMI >=35 and BMI <40 :
            print("Obese Class II")
        elif BMI >=40 :
            print("Obese Class III")
    
    elif gender == "Female" or gender == "female":
        a = eval(input("Enter your weight in kg: "))
        b = eval(input("Enter your height in Meter: "))
        height_square = b*b
        BMI = a/height_square
        print("Your BMI is : " , BMI)
        if BMI<16 :
            print("Severe Thinness")
        elif BMI >=16 and BMI <17 :
            print("Moderate Thinness")
        elif BMI >=17 and BMI < 18.5 :
            print("Mild Thinness")
        elif BMI >=18.5 and BMI <25 :
            print("normal")
        elif BMI >=25 and BMI <30 : 
            print("Overweight")
        elif BMI >=30 and BMI <35 :
            print("Obese Class I")
        elif BMI >=35 and BMI <40 :
            print("Obese Class II")
        elif BMI >=40 :
            print("Obese Class III") 
    else :
        print("invalid Gender")
        
else :
    print("invalid Age")
# Out:
# Enter your age between (2 - 120): 35
# For your BMI Report Enter your Gender (Male/Female): male
# Enter your weight in kg: 63
# Enter your height in Meter: 1.65
# Your BMI is :  23.140495867768596
# normal

# %% [markdown]
# # ASSIGNMENT 2

# %%
n = int(input("enter your mobile number: "))
add = 0
while n > 0:
    a = n % 10
    add = add + a
    n = n // 10
print(f'''sum of your mobile numbers dijits is: {add}''')
NewAdd = add % 10
NewRem = add //10
newsum1 = NewAdd + NewRem
if newsum1 >=10:
    print(f"the sum of all dijits of {add} is: ",newsum1)
    newadd1 = newsum1%10
    newrem1 = newsum1//10
    print(f"sum of all dijits of {newsum1} is : ",newadd1+newrem1)
else:
    print(f'''the sum of {add}\'S all dijits is  is: {NewAdd + NewRem}  ''')
